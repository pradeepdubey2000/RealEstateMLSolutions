# %%
import numpy as np
import pandas as pd

# %%
flats = pd.read_csv(r'C:\Users\pradeep dubey\Desktop\project\Real_State_Project\data\processed\flats_cleaned.csv')
houses = pd.read_csv(r'C:\Users\pradeep dubey\Desktop\project\Real_State_Project\data\processed\houses_cleaned.csv')

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                                      property_name property_type  \
# 0                 4 BHK Flat in Sector 70A Gurgaon          flat
# 1   5 Bedroom House for sale in Sector 111 Gurgaon         house
# 2                  3 BHK Flat in Sector 74 Gurgaon          flat
# 3    6 Bedroom House for sale in Sector 55 Gurgaon         house
# 4  4 Bedroom House for sale in Sushant Lok Phase 1         house
#
#                         society  price  price_per_sqft    area  \
# 0          bptp astaire gardens   1.60          8658.0  1848.0
# 1        puri diplomatic greens   9.00         11250.0  8000.0
# 2                   m3m skywalk   2.25         12500.0  1800.0
# 3                   independent   5.60         20741.0  2700.0
# 4  sushant lok 1 builder floors   2.45          7756.0  3159.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0  Super Built up area 1848(171.68 sq.m.)Built Up...        4         4
# ...

# %%
import os

# Define the absolute path to the processed data folder
data_path = r"C:\Users\pradeep dubey\Desktop\project\Real_State_Project\data\processed"

# Create the directory if it doesn't exist
os.makedirs(data_path, exist_ok=True)

# Assuming df is already defined, save the DataFrame to the specified path
df.to_csv(os.path.join(data_path, "gurgaon_properties.csv"), index=False)

# %%
df.shape
# Out:
# (3961, 20)
